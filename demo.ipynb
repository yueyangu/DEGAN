# %% [markdown]
# This demo showcases an example in this paper

# %%
from train_val_test import *

# %%
# Set up GPU environment
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.config.experimental.set_memory_growth(physical_devices[1], True)

# %%
# the channel name of time series data
uniChannel = 'T16_CBV'
# the window length to extract subsequence of original time series data
window_length = 100
# milepost to be considered
MP_list = [81,82,84,86,88]
# threshold of anomaly prediciotn number in the validation step
t = 10
# set a reandom seed for reproduction
tf.random.set_seed(2022)
# Bandwidth of kernel density estimation
kde_bandwidth = 50
# leanring rate of Generator
glr=0.001
# learning rate of Discriminator
dlr=0.0001
# Maximum training epochs
total_epochs = 500
# Validation frequency
v_freq = 5
result_df, metrics = GAN_train_test(kde_bandwidth, 1,t,uniChannel, MP_list, window_length, glr,dlr, total_epochs,v_freq)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# model saved, best epoch = 70
#   0%|          | 0/500 [00:00<?, ?it/s]
# model saved, best epoch = 60
#   0%|          | 0/500 [00:00<?, ?it/s]
# model saved, best epoch = 330
#   0%|          | 0/500 [00:00<?, ?it/s]
# model saved, best epoch = 65
#   0%|          | 0/500 [00:00<?, ?it/s]
